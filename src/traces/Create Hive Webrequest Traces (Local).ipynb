# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from trace_utils import create_hive_trace_table, exec_hive

# %%
create_hive_trace_table('traces', 'test')

# %%
exec_hive('query', priority = False)
# Out:
# hive -e " query "
